# %% [markdown]
# # PRASOON KISHORE
#
# # GRIP @ The Sparks Foundation
#
#  Task-2 : Predicting the optimum number of cluster of Iris Dataset

# %%
# Importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import datasets
import sklearn.metrics as sm

# %%
#importing iris dataset and converting into pandas dataframe
iris = datasets.load_iris()
iris_df = pd.DataFrame(iris.data, columns = iris.feature_names)
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
#importing KMean for cluster analsis

from sklearn.cluster import KMeans
x = iris_df.iloc[:, [0, 1, 2, 3]].values
wcss = []

#Calculating cluster value through iteration
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)

# %%
# Plotting the results onto a line graph
plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.grid(True)

# %% [markdown]
# We can see from above 'Elbow Method',the optimum cluster value is '3'.

# %%
# Applying kmeans to the dataset
kmeans = KMeans(n_clusters = 3, init = 'k-means++',
                max_iter = 300, n_init = 10, random_state = 0)
y_kmeans = kmeans.fit_predict(x)

# %%
# Visualising the clusters between sepal length and sepal width
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1],
            s = 70, c = 'red', label = 'Iris-setosa')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1],
            s = 70, c = 'blue', label = 'Iris-versicolour')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1],
            s = 70, c = 'green', label = 'Iris-virginica');

# Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 70, c = 'yellow', label = 'Centroids');
plt.legend();
plt.figure(figsize = (12,8));

# %%
# Visualising the clusters petal length and petal width
plt.scatter(x[y_kmeans == 0, 2], x[y_kmeans == 0, 3],
            s = 70, c = 'red', label = 'Iris-setosa')
plt.scatter(x[y_kmeans == 1, 2], x[y_kmeans == 1, 3],
            s = 70, c = 'blue', label = 'Iris-versicolour')
plt.scatter(x[y_kmeans == 2, 2], x[y_kmeans == 2, 3],
            s = 70, c = 'green', label = 'Iris-virginica');

# Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 2], kmeans.cluster_centers_[:, 3], 
            s = 70, c = 'yellow', label = 'Centroids');
plt.legend();
plt.figure(figsize = (12,8));

# %%
# Visualising the clusters sepal length and petal length
plt.scatter(x[y_kmeans == 0, 2], x[y_kmeans == 0, 3],
            s = 70, c = 'red', label = 'Iris-setosa')
plt.scatter(x[y_kmeans == 1, 2], x[y_kmeans == 1, 3],
            s = 70, c = 'blue', label = 'Iris-versicolour')
plt.scatter(x[y_kmeans == 2, 2], x[y_kmeans == 2, 3],
            s = 70, c = 'green', label = 'Iris-virginica');

# Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 2], 
            s = 70, c = 'yellow', label = 'Centroids');
plt.legend();
plt.figure(figsize = (12,8));
